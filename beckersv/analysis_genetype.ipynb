# %% [markdown]
# # NS-Forest Gene Type Comparison Pipeline Test
#
# On the NS-Forest library's provided `demo_data`.

# %%
import sys
import os
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
import matplotlib.pyplot as plt
import plotly.io as pio
pio.renderers.default = "notebook"
import nsforest as ns
from nsforest import utils

import pipeline_nsforesting_genetype as nsfp

# %% [markdown]
# ## Object Initialization

# %%
test_pipeline = nsfp.NSForestComparison(
    code_folder="/Users/vbecker/Desktop/NSForest-ncRNA",
    data_folder="../demo_data",
    output_folder="../demo_output")

# %% [markdown]
# ## Set Data

# %%
test_pipeline.set_data(
    dataset_file="adata_layer1.h5ad",
    annotation_file="gencode.v47.annotation_txLength.csv",
    cluster_header="cluster",
    print_info=True)
# Out:
# Dataset 'adata_layer1.h5ad' loaded successfully. Here are some details:
# Number of cells: 871
# Number of genes: 16497
# Available columns in adata.obs: ['cluster']
# Available columns in adata.var: []
# Feature Value Counts: Feature
# gene    78724
# Name: count, dtype: int64
# Sum of Duplicated Gene Names: 1610
# /Users/vbecker/Desktop/NSForest-ncRNA/beckersv/pipeline_nsforesting_genetype.py:85: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   gencode = pd.read_csv(os.path.join(self.data_folder, self.annotation_file))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 test_pipeline.set_data(
#       2     dataset_file="adata_layer1.h5ad",
#       3     annotation_file="gencode.v47.annotation_txLength.csv",
#       4     cluster_header="cluster",
#
# ...
